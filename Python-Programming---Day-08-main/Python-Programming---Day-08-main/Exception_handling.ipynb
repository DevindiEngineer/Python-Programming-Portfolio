# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8376/1353120783.py in <cell line: 0>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# can have one or more except statments in a try - except block

# %%
try:
  print(x)
except:
  print("An Error Occured") # any error dont crash the prgm and print this
# Out:
# An Error Occured

# %%
x=10
try:
  print(x)
except:
  print("An Error Occured") # no error so print the actual result
# Out:
# 10

# %%
x=10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_8376/2211229741.py in <cell line: 0>()
# ----> 1 x=10/0
#
# ZeroDivisionError: division by zero

# %%
try:
  x=10/0
except:
  print("You cant devide by zero")
# Out:
# You cant devide by zero

# %%
num = int(input("Enter a number : "))
print("Valid number :",num)
# Out:
# Enter a number : Devindi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8376/395880185.py in <cell line: 0>()
# ----> 1 num = int(input("Enter a number : "))
#       2 print("Valid number :",num)
#
# ValueError: invalid literal for int() with base 10: 'Devindi'

# %%
num = int(input("Enter a number : "))
print("Valid number :",num)
# Out:
# Enter a number : 456
# Valid number : 456

# %%
try:
  num = int(input("Enter a number : "))
  print("Valid number :",num)
except:
  print("Error : Not a valid number")
# Out:
# Enter a number : Devindi
# Error : Not a valid number

# %%
try:
  num = int(input("Enter a number : "))
  print("Valid number :",num)
except:
  print("Error : Not a valid number")
# Out:
# Enter a number : 57545
# Valid number : 57545

# %%
try:
  num = int(input("Enter a number : "))
except ValueError:
  print("Invalid number!")
else:
  print("Success! You entered : ",num)
finally:
  print("This always runs(cleanup,logging,etc.).")
# Out:
# Enter a number : 123456
# Success! You entered :  123456
# This always runs(cleanup,logging,etc.).

# %%
try:
  num = int(input("Enter a number : "))
except ValueError:
  print("Invalid number!")
else:
  print("Success! You entered : ",num)
finally:
  print("This always runs(cleanup,logging,etc.).")
# Out:
# Enter a number : dew
# Invalid number!
# This always runs(cleanup,logging,etc.).

# %%
try:
  print(value)
except NameError as e:
  print("Here I can insert customized message",e)
# Out:
# Here I can insert customized message name 'value' is not defined

# %% [markdown]
# Logical errors - due to mustakes done by the programmer

# %% [markdown]
# EX : 1

# %%
length = 5
width = 10
area = length + width # wrong mathematical operator - not + should be *
print(area)
# Out:
# 15

# %%
length = 5
width = 10
area = length * width # correct
print(area)
# Out:
# 50

# %% [markdown]
# EX : 2

# %%
a = 12+3*4 # we need output as 60 but gives 24
print(a)
# Out:
# 24

# %%
a = (12+3) * 4
print(a)
# Out:
# 60

# %%
try:
  value = int(input("Enter a value : "))
  print(value/value)
except ValueError:
  print("Bad Input...")
except ZeroDivisionError:
  print("Cannot divide by zero")
# Out:
# Enter a value : K
# Bad Input...

# %%
try:
  value = int(input("Enter a value : "))
  print(value/value)
except ValueError:
  print("Bad Input...")
except ZeroDivisionError:
  print("Cannot divide by zero")
# Out:
# Enter a value : 25
# 1.0

# %%
try:
  value = int(input("Enter a value : "))
  print(value/value)
except ValueError:
  print("Bad Input...")
except ZeroDivisionError:
  print("Cannot divide by zero")
# Out:
# Enter a value : 0
# Cannot divide by zero

# %% [markdown]
# Exercises

# %%
value = input ("Enter a value : ")
print(10/value)
# Out:
# Enter a value : 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8376/3269312944.py in <cell line: 0>()
#       1 value = input ("Enter a value : ")
# ----> 2 print(10/value)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
try:
  print(int("10")+5)
except ValueError:
  print("Error!")
# Out:
# 15

# %%
try:
  val = int("xyz")
except ValueError:
  print("Invalid")
finally:
  print()
# Out:
# Invalid

# %% [markdown]
# Catch multipe exceptions

# %%
try:
  val = int("xyz")
except (ValueError,TypeError):
  print("Invalid")
finally:
  print()
# Out:
# Invalid

# %%
try:
  d = {"a:":1}
  print(d["b"])
except KeyError:
  print("Missing key")
else:
  print("No Error")
# Out:
# Missing key

# %%
answer = input("Enter the marks : ")
try:
  answer=int(answer)
  if not(answer>=0 and answer<=100):
    print("Outside the range! Marks must be between 0 to 100")
  else:
    print("Valid marks entered!")
except ValueError:
  print("Invalid input! Please enter a number !")
# Out:
# Enter the marks : -100
# Outside the range! Marks must be between 0 to 100

# %%
answer = input("Enter the marks : ")
try:
  answer=int(answer)
  if not(answer>=0 and answer<=100):
    print("Outside the range! Marks must be between 0 to 100")
  else:
    print("Valid marks entered!")
except ValueError:
  print("Invalid input! Please enter a number !")
# Out:
# Enter the marks : 1000
# Outside the range! Marks must be between 0 to 100

# %%
answer = input("Enter the marks : ")
try:
  answer=int(answer)
  if not(answer>=0 and answer<=100):
    print("Outside the range! Marks must be between 0 to 100")
  else:
    print("Valid marks entered!")
except ValueError:
  print("Invalid input! Please enter a number !")
# Out:
# Enter the marks : Devindi
# Invalid input! Please enter a number !

# %%
answer = input("Enter the marks : ")
try:
  answer=int(answer)
  if not(answer>=0 and answer<=100):
    print("Outside the range! Marks must be between 0 to 100")
  else:
    print("Valid marks entered!")
except ValueError:
  print("Invalid input! Please enter a number !")
# Out:
# Enter the marks : 93
# Valid marks entered!
