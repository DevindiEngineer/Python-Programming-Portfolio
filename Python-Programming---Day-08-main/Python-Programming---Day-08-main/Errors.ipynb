# %% [markdown]
# # Syntax Errors

# %%
x=15
if x>10
  print("Hello")
# Out:
#   File "/tmp/ipykernel_3592/2768759811.py", line 2
#     if x>10
#            ^
# SyntaxError: expected ':'

# %%
x=15
if x>10:
  print("Hello")
# Out:
# Hello

# %% [markdown]
# # systax errors - incorrect indentation

# %%
for i in range(5):
print(i)
# Out:
#   File "/tmp/ipykernel_3592/3695896917.py", line 2
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Systax errors - missspelled python keywords

# %%
deff calculate():
  pass
# Out:
#   File "/tmp/ipykernel_3592/1211976457.py", line 1
#     deff calculate():
#          ^
# SyntaxError: invalid syntax

# %%
def calculate():
  pass

# %% [markdown]
# # unmatched or brocken string

# %%
print("Hello)
# Out:
#   File "/tmp/ipykernel_3592/1371898898.py", line 1
#     print("Hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# missing parantheiss

# %%
print "Hi"
# Out:
#   File "/tmp/ipykernel_3592/2419407535.py", line 1
#     print "Hi"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# # Runtime error

# %% [markdown]
# name error

# %%
number = 10
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3592/3421711952.py in <cell line: 0>()
#       1 number = 10
# ----> 2 print(num)
#
# NameError: name 'num' is not defined

# %%
number =10
print(number)
# Out:
# 10

# %% [markdown]
# index errors

# %%
num_list = [1,2,3]
print(num_list[10]) # 10 is out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3592/744808862.py in <cell line: 0>()
#       1 num_list = [1,2,3]
# ----> 2 print(num_list[10])
#
# IndexError: list index out of range

# %%
num_list = [1,2,3]
print(num_list[2]) # only 0,1,2 can use without error within the range
# Out:
# 3

# %% [markdown]
# type errors

# %%
str_name = 'John' + 12
print(str_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3592/4180396595.py in <cell line: 0>()
# ----> 1 str_name = 'John' + 12
#       2 print(str_name)
#
# TypeError: can only concatenate str (not "int") to str

# %%
str_name = 23 + 12
print(str_name)

str_name = 'John' + ' Buttler'
print(str_name)
# Out:
# 35
# John Buttler

# %% [markdown]
# value error

# %%
print(int("hello"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3592/148294692.py in <cell line: 0>()
# ----> 1 print(int("hello"))
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
i=10.00
print(int(i))
print(type(i))
# Out:
# 10
# <class 'float'>

# %% [markdown]
# import error / module not found error

# %%
import Math #incorrect module name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3592/3790290868.py in <cell line: 0>()
# ----> 1 import Math
#
# ModuleNotFoundError: No module named 'Math'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import math #correct module name - math in lower case

# %%
import pandas

# %%
import datetime

# %%
import numpy # numerical python

# %%
import matplotlib

# %% [markdown]
# key error

# %%
data = {"name":"Alex"}
data[age]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3592/2189997776.py in <cell line: 0>()
#       1 data = {"name":"Alex"}
# ----> 2 data[age]
#
# NameError: name 'age' is not defined

# %%
data = {"name":"Alex"}
data["name"]
# Out:
# 'Alex'

# %% [markdown]
# Attribute error

# %%
x =10
x.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3592/3621343284.py in <cell line: 0>()
#       1 x =10
# ----> 2 x.append(5)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
x = [10]
x.append(5)
print(x)
# Out:
# [10, 5]

# %% [markdown]
# Zero devision error

# %%
10/1
# Out:
# 10.0

# %%
10/2.55
# Out:
# 3.9215686274509807

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3592/530406163.py in <cell line: 0>()
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# IOError / OSError # permissions/device errors

# %%
f = open("my_file.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3592/2126862459.py in <cell line: 0>()
# ----> 1 f = open("my_file.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_file.txt'

# %%
# uploaded the text file-Open the file directly by its name now that it is uploaded
with open("test.txt", "r") as f:
    print(f.readline().strip())
# Out:
# Hellooo Python students!!!
