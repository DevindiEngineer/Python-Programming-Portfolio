# %% [markdown]
# #Function without parameters

# %%
def greetings():
    print("Hello World!");

# %%
greetings()
greetings()
greetings()
# Out:
# Hello World!
# Hello World!
# Hello World!

# %% [markdown]
# #Function with parameters

# %%
def add(a,b):
    print(a+b)
add(3,5)
# Out:
# 8

# %%
add(10,35)
# Out:
# 45

# %%
def calculate(a,b):
    print ("Total : ",a+b)

# %%
calculate(10,20)
# Out:
# Total :  30

# %%
calculate(1050,2050)
# Out:
# Total :  3100

# %%
def add (a,b):
    return a+b
add(10,20)
# Out:
# 30

# %%
print(add(10,20))
# Out:
# 30

# %%
x=add(10,20)
print(x)
# Out:
# 30

# %%
def greet(name):
    print(f"Hello {name}!")

# %%
greet("Senaka")
# Out:
# Hello Senaka!

# %%
greet("GPT 2.0")
# Out:
# Hello GPT 2.0!

# %%
greet(9876543210)
# Out:
# Hello 9876543210!

# %%
def greet(name):
    print (f"Hello {name}!")
name=input("What is your name?")
greet(name)
# Out:
# What is your name? Devindi
# Hello Devindi!

# %%
def greet(name1,name2):
    print(f"Hello {name1} {name2}!")

# %%
name1=input("What is your first name ? ")
name2=input("What is your last name ?")
greet(name1,name2)
# Out:
# What is your first name ?  Devindi
# What is your last name ? Wickramasinghe
# Hello Devindi Wickramasinghe!

# %% [markdown]
# #Functions with return value

# %% [markdown]
# #with return statement need to take a variable

# %%
def calculator(a,b):
    return a+b

# %%
result=calculator(10,20) 
print("Sum : ",result)
# Out:
# Sum :  30

# %% [markdown]
# #Without return statement no need just call the method(function)

# %%
def calculator(a,b):
    print(a+b)

# %%
calculator(10,20)
# Out:
# 30

# %% [markdown]
# #Continue Key Word - Skips the current iteration and moves to the next one

# %%
for i in range(1,11,1):
    if i==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
for i in range(1,11,1):
    if i!=5:
        continue
    print(i)
# Out:
# 5

# %% [markdown]
# #Pass Key Word (not decided yet - just naming)
# does nothing and wanna leave a block empty

# %%
for i in range(1,11,1):
    pass #placeholder for future code

# %%
def calculate():
    pass

# %% [markdown]
# #break Key Word - immediately exits the loop(stop the loop)

# %%
for i in range (0,11,1):
    if i==5:
        break
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #Exercises

# %%
for i in range(1,4):
    for j in range(1,4):
        if j==2:
            continue
        print(f"i={i},j={j}")
# Out:
# i=1,j=1
# i=1,j=3
# i=2,j=1
# i=2,j=3
# i=3,j=1
# i=3,j=3

# %%
def my_function():
    pass
print("Hello!")
# Out:
# Hello!

# %%
for i in range(3):
    if i==1:
        pass
    print(i)
# Out:
# 0
# 1
# 2
