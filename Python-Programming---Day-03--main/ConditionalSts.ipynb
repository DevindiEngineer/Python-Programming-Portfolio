# %%
age=int(input("Input your age : "))
if age>18:
    print("Adult")
else:
    print("Minor")
# Out:
# Input your age :  21
# Adult

# %%
studentMarks=98
if studentMarks>=50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
marks=int(input("Input student marks : "))
if marks>=75:
    print("A Grade")
elif marks>=65:
    print("B Grade")
elif marks>=50:
    print("C Grade")
else:
    print("Fail")
# Out:
# Input student marks :  99
# A Grade

# %%
number=int(input("Enter the number : "))
if number>0:
    print("Number is Positive")
elif number<0:
    print("Number is Negative!")
else:
    print("Number is 0")
# Out:
# Enter the number :  -5
# Number is Negative!

# %%
number=int(input("Enter the number : "))
if number>=0:
    if number>0:
        print("Number is positive!")
    else:
        print("Number is 0")
else:
    print("Number is negative!")
# Out:
# Enter the number :  0
# Number is 0

# %%
number=75
if number!=0:
    if number>0:
        print("Number is positive!")
    else:
        print("Number is negative!")
else:
    print("Number is 0!")
# Out:
# Number is positive!

# %%
number=int(input("Enter the number : "))
if number%2==0:
    print("Number is even!")
else:
    print("Number is odd!")
# Out:
# Enter the number :  3
# Number is odd!

# %%
name=input("Enter your name : ")
marks=int(input("Enter your marks : "))
if marks>75:
    print("Hi!"+name+", "+"You have got an A Grade.")
elif marks>65:
    print("Hi!"+name+", "+"You have got a B Grade.")
elif marks>50:
    print("Hi!"+name+", "+"You have got a C Grade.")
else:
    print("Hi!"+name+", "+"You have got a F Garde.")
# Out:
# Enter your name :  Devindi
# Enter your marks :  97
# Hi!Devindi, You have got an A Grade

# %%
marks=int(input("Enter the marks : "))
if 100>=marks>=0:
    if marks>=90:
        print("A")
    elif marks>=80:
        print("B")
    elif marks>=70:
        print("C")
    elif marks>=60:
        print("D")
    else:
        print("F")
else:
    print("Invalid score entered...!")
# Out:
# Enter the marks :  920
# Invalid score entered...!

# %%
x=100
if x>100:
    k=x*2
    if x>=200:
        k=k*3
    elif k<300:
        k=k*4
    else:
        k=k*5
else:
    k=x*3
print(k)
# Out:
# 300

# %%
number1=int(input("Enter number 1 : "))
number2=int(input("Enter number 2 : "))
if number1==number2:
    print("Number 1 equals number 2!")
elif number1>number2:
    print("Number 1 is greated than number 2!")
else:
    print("Number 2 is greated than number 1!")
# Out:
# Enter number 1 :  1000
# Enter number 2 :  1000
# Number 1 equals number 2!
