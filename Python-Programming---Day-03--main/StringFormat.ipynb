# %%
name1=input("Enter the name?")
number1=input("Enter the number?")
print(number1)
print(type(number1))
# Out:
# Enter the name? dew
# Enter the number? 85
# 85
# <class 'str'>

# %%
name2=input("Enter the name?")
number2=int(input("Enter the number?"))
print(number2)
print(type(number2))
# Out:
# Enter the name? Devindi
# Enter the number? 56
# 56
# <class 'int'>

# %%
num1=int(input("Enter number 1 : "))
num2=int(input("Enter number 2 : "))
sum=num1+num2
print(sum)
# Out:
# Enter number 1 :  45
# Enter number 2 :  5
# 50

# %%
first_name=input("Enter your first name : ")
second_name=input("Enter your second name : ")
age=int(input("Enter you age : "))
print(first_name,second_name,"is",age,"years old!")
# Out:
# Enter your first name :  Dew
# Enter your second name :  Wicky
# Enter you age :  21
# Dew Wicky is 21 years old!

# %%
first_name=input("Enter your first name : ")
second_name=input("Enter your second name : ")
age=int(input("Enter you age : "))
print(first_name)
print(second_name)
print(age)
# Out:
# Enter your first name :  Dew
# Enter your second name :  Wicky
# Enter you age :  21
# Dew
# Wicky
# 21

# %%
#additional space
first_name=input("Enter your first name : ")
second_name=input("Enter your second name : ")
print(first_name," ",second_name)
# Out:
# Enter your first name :  Dew
# Enter your second name :  Wicky
# Dew   Wicky

# %%
#Formatted String method
first_name=input("Enter your first name : ")
second_name=input("Enter your second name : ")
age=int(input("Enter you age : "))
print(f"My name is {first_name} {second_name},I'm {age} years old!")
# Out:
# Enter your first name :  Dew
# Enter your second name :  Wicky
# Enter you age :  21
# My name is Dew Wicky,I'm 21 years old!

# %%
print("Hello\nWorld\nHow\nAre\nYou!")
# Out:
# Hello
# World
# How
# Are
# You!

# %%
#multiline speech
multiline_speech="""This is line one.Thiss is line two.
and this is the
end."""
print(multiline_speech)

# %% [markdown]
# ###Indexing

# %%
#Forward indexing
name="Hello"
print(name[0])
print(name[4])
# Out:
# H
# o

# %%
#Reverse indexing
name="Hello"
print(name[-1])
print(name[-5])
# Out:
# o
# H

# %%
name="Hello"
print(name[0:5])
# Out:
# Hello

# %%
name="Hello"
print(name[1:4])
# Out:
# ell

# %%
name="Hello"
print(name[1:])
# Out:
# ello

# %%
name="Hello"
print(name[3:])
# Out:
# lo

# %% [markdown]
# #Slicing

# %%
name="Hello"
print(name.upper())
print(name.lower())
# Out:
# HELLO
# hello
