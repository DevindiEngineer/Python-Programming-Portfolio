# %%
correctPassword = "2005ABC"
password=input("Enter your password :")
while password!=correctPassword:
    print("Incorrect Password. Try again!")
    password=input("Enter your password :")
print("Access Granted!")
# Out:
# Enter your password : 1990
# Incorrect Password. Try again!
# Enter your password : 2005ABC
# Access Granted!

# %%
while True:
    command = input("Type 'exit' to quite : ")
    if command == "exit":
        print("You typed exit correctly!")
        break
# Out:
# Type 'exit' to quite :  hi
# Type 'exit' to quite :  yes
# Type 'exit' to quite :  no
# Type 'exit' to quite :  exit
# You typed exit correctly!

# %% [markdown]
# #Waiting for a condition to change

# %%
import time
battery=10
while battery>0:
    print("Battery level : ",battery)
    battery-=1
    time.sleep(1)
print("Battery Empty!")
# Out:
# Battery level :  10
# Battery level :  9
# Battery level :  8
# Battery level :  7
# Battery level :  6
# Battery level :  5
# Battery level :  4
# Battery level :  3
# Battery level :  2
# Battery level :  1
# Battery Empty!

# %% [markdown]
# #Counting with a variable

# %%
i=0
while i<5:
    print (i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #validating user prints

# %%
age = -1
while age <= 0:
    age=int(input("Enter a valid age!"))
print("Thank you!!!")
# Out:
# Enter a valid age! 0
# Enter a valid age! -50
# Enter a valid age! -20
# Enter a valid age! 21
# Thank you!!!

# %% [markdown]
# #Menu driven programmes

# %%
choice=""
while choice!="3":
    print("1.Add\n2.View\n3.Exit")
    choice=input("Choose an option : ")
print("Good Bye!")
# Out:
# 1.Add
# 2.View
# 3.Exit
# Choose an option :  1
# 1.Add
# 2.View
# 3.Exit
# Choose an option :  2
# 1.Add
# 2.View
# 3.Exit
# Choose an option :  3
# Good Bye!
